# %%
# Import thư viện cần thiết
from google.oauth2 import service_account
from googleapiclient.discovery import build
import os
import pandas as pd
from bot.configs.config import FANPAGE_FACEBOOK_URL, SPREADSHEET_ID

# %%
class Font:
    def __init__(self, name, keys, links, images, post_link, messages, tags, description):
        self.name: str = name
        self.keys: list = keys
        self.links: list = links
        self.images: list = images
        self.post_link: str = post_link
        self.messages: list = messages
        self.tags: list = tags
        self.description = description

    def __str__(self):
        return f'Name: {self.name}\nKeys: {self.keys}\nLinks: {self.links}\nImages: {self.images}\nPost link: {self.post_link}\nMessages: {self.messages}\nTags: {self.tags}\nDescription: {self.description}'


def flatten_2d_string_array(array):
    if array is None:
        return []
    result = []
    for row in array:
        for item in row:
            result.append(item)
    return result

# %%
class GoogleSheetsReader:
    def __init__(self):
        scopes = ['https://www.googleapis.com/auth/spreadsheets']
        key_file = os.path.join(os.path.dirname(__file__), '..', '..', 'key', 'nvnfont.json')
        credentials = service_account.Credentials.from_service_account_file(key_file, scopes=scopes)
        self.service = build('sheets', 'v4', credentials=credentials)
        self.spreadsheet_id = SPREADSHEET_ID
        self.df = pd.DataFrame()

    def get_first_sheet_name(self):
        spreadsheet = self.service.spreadsheets().get(spreadsheetId=self.spreadsheet_id).execute()
        sheet_properties = spreadsheet['sheets']
        return sheet_properties[0]['properties']['title']

    def get_data_as_dataframe(self, sheet_name):
        result = self.service.spreadsheets().values().get(spreadsheetId=self.spreadsheet_id, range=sheet_name).execute()
        values = result.get('values', [])
        df = pd.DataFrame(values[1:], columns=values[0])
        return df

    def get_data_first_sheet(self):
        sheet_name = self.get_first_sheet_name()
        self.df = self.get_data_as_dataframe(sheet_name)
        self.df = self.df.fillna('')
        return self.df

    def get_image_unique(self) -> list:
        images = set()
        image_check = flatten_2d_string_array(self.df['Keys'].str.split('\n'))
        for image in image_check:
            if image != '':
                images.add(image)
        return list(images)

    def get_link_unique(self) -> list:
        links = set()
        link_check = flatten_2d_string_array(self.df['Links'].str.split('\n'))
        for link in link_check:
            if link != '':
                links.add(link)
        return list(links)

    def get_message_unique(self) -> list:
        messages = set()
        message_check = flatten_2d_string_array(self.df['Messages'].str.split('\n'))
        for message in message_check:
            if message != '':
                messages.add(message)
        return list(messages)

    def get_tag_unique(self) -> list:
        tags = set()
        tag_check = flatten_2d_string_array(self.df['Tags'].str.split('\n'))
        for tag in tag_check:
            if tag != '':
                tags.add(tag)
        return list(tags)

    def get_result(self) -> dict:
        self.get_data_first_sheet()
        unique_keys = set()
        unique_images = self.get_image_unique()
        unique_links = self.get_link_unique()
        unique_messages = self.get_message_unique()
        unique_tags = self.get_tag_unique()
        fonts = []
        for index, row in self.df.iterrows():
            # Name	Keys	Links	Images	Post_Link	Messages	Tags	Description																		
            name = row.get('Name')
            if name == '':
                continue
            #     nếu post link ko có thì mặc định là fb.com/nvnfont
            post_link = row.get('Post_Link') if row.get('Post_Link') != '' else FANPAGE_FACEBOOK_URL
            description = row.get('Description') if row.get('Description') != '' else 'Không có mô tả'
            keys_temp = row.get('Keys').split('\n')
            keys = []
            links = [link for link in row.get('Links').split('\n') if link != '']
            images = [image for image in row.get('Images').split('\n') if image != '']
            messages = [message for message in row.get('Messages').split('\n') if message != '']
            tags = [tag for tag in row.get('Tags').split('\n') if tag != '']
            for key in keys_temp:
                if key not in unique_keys:
                    unique_keys.add(key)
                    keys.append(key)
            font = Font(name, keys, links, images, post_link, messages, tags, description)
            fonts.append(font)
        return {
            'fonts': fonts,
            'unique_keys': list(unique_keys),
            'unique_images': unique_images,
            'unique_links': unique_links,
            'unique_messages': unique_messages,
            'unique_tags': unique_tags
        }


# Cấu hình thông tin truy cập API theo đường dẫn tuyệt đối  
# nằm ở thư mục key cùng cấp với bot 
key_file = '../../keys/nvnfont.json'
spreadsheet_id = ''

# Khởi tạo đối tượng GoogleSheetsReader
gsr = GoogleSheetsReader(key_file, spreadsheet_id)

#  lấy dữ liêu
result = gsr.get_result()
fonts = result['fonts']
for font in fonts:
    print(font)
    print('-----------------------')
# Out:
# Name: NVN Vintage
# Keys: ['Vintage', 'vintage']
# Links: ['https://tinyurl.com/NVNVintAge']
# Images: ['https://i.postimg.cc/FKG5fsJ7/243020779-384463130010732-1288129108816872004-n.jpg', 'http://t0.gstatic.com/licensed-image?q=tbn:ANd9GcSBamUyz4iu9-A6JDBv_nObmIUL58Msf8B4vb4NhfkLi_jDwOJJJTgfGTYY70yggpH4uME4i9bRWWIY7MfUMAY']
# Post link: https://www.facebook.com/NVNFONT/posts/384467533343625
# Messages: ['Nếu {{name}} muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé !!']
# Tags: ['1']
# Description: dsfd
# -----------------------
# Name: NVN Neography
# Keys: ['Neography']
# Links: ['https://tinyurl.com/NVN-Neography']
# Images: ['https://i.postimg.cc/G2jdrxbT/240761895-362360298887682-9151394716837352826-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/362360588887653
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: sdf
# -----------------------
# Name: NVN Excellent Display
# Keys: ['Excellent Display']
# Links: ['https://by.com.vn/NVN-Excellent']
# Images: ['https://i.postimg.cc/MpDGzwtp/241724447-374096174380761-3602829558210574073-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/374096444380734
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['3']
# Description: sdf
# -----------------------
# Name: NVN Astonia
# Keys: ['Astonia']
# Links: ['https://by.com.vn/NVN-Astonia']
# Images: ['https://i.postimg.cc/jqmZtwSZ/245902575-396492065474505-5201853648298594866-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/396491408807904
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['4']
# Description: Description
# -----------------------
# Name: NVN Funky Signature
# Keys: ['Funky']
# Links: ['https://by.com.vn/NVN-Funky']
# Images: ['https://i.postimg.cc/xTHZJykX/256767130-416698706787174-5636398302501510470-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/416698666787178
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['5']
# Description: dsfd
# -----------------------
# Name: NVN Hillstown
# Keys: ['Hillstown']
# Links: ['https://by.com.vn/NVNHillstown']
# Images: ['https://i.postimg.cc/63nH2B3D/257717877-419254776531567-2469703780791543703-n.png']
# Post link: https://www.facebook.com/NVNFONT/posts/419256613198050
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['6']
# Description: sdf
# -----------------------
# Name: NVN Cut Along
# Keys: ['Cut Along']
# Links: ['https://by.com.vn/NVN-CutAlong-']
# Images: ['https://i.postimg.cc/9Q21S6Lp/244396282-389180289539016-7012997832500865052-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/389180326205679
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['7']
# Description: sdf
# -----------------------
# Name: NVN Helvetica
# Keys: ['Helvetica']
# Links: ['https://tinyurl.com/NVN-Helvetica']
# Images: ['https://i.postimg.cc/HnHR2r8w/240830304-363620162095029-1513381745822576729-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts
n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/156271772829870
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['1']
# Description: Description
# -----------------------
# Name: NVN Operetta12
# Keys: ['Operetta12']
# Links: ['https://tinyurl.com/ykbuubw5']
# Images: ['https://i.postimg.cc/RZwcbKVn/121614981-156269849496729-5912963480317253684-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/156271772829870
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['1']
# Description: dsfd
# -----------------------
# Name: NVN Square Slabserif 71
# Keys: ['Square Slabserif']
# Links: ['https://tinyurl.com/2574mmdy']
# Images: ['https://i.postimg.cc/V62qVRMn/121696112-156269936163387-8916963124183845284-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/156271772829870
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: sdf
# -----------------------
# Name: NVN Little Princess
# Keys: ['Little Princess']
# Links: ['https://tinyurl.com/NVN-Little-Princess']
# Images: ['https://i.postimg.cc/q7S6J7Rd/121255207-155294699594244-5027969970283564186-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/155295016260879
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: sdf
# -----------------------
# Name: NVN Verdana 8pt
# Keys: ['Verdana 8pt']
# Links: ['https://tinyurl.com/NVN-PixelFJVerdana8pt']
# Images: ['https://i.postimg.cc/GmNmY51F/121300898-154720282985019-7866769818119145600-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/154721926318188
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: Description
# -----------------------
# Name: NVN The Tide
# Keys: ['The Tide']
# Links: ['https://tinyurl.com/NVN-The-Tide']
# Images: ['https://i.postimg.cc/jSWss4JL/120914314-153462533110794-695309343461297694-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/153462959777418
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: dsfd
# -----------------------
# Name: NVN My Everything
# Keys: ['My Everything']
# Links: ['https://tinyurl.com/NVN-My-Everything']
# Images: ['https://i.postimg.cc/mDTfFYh3/120773200-151871246603256-4191736708206773768-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/151871439936570
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: sdf
# -----------------------
# Name: NVN Crowlen
# Keys: ['Crowlen']
# Links: ['https://tinyurl.com/NVN-CrowlenEdit']
# Images: ['https://i.postimg.cc/QMQV3JRc/120723821-150664066723974-4156326001016091067-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/150664630057251
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: sdf
# -----------------------
# Name: NVN Cutive Mono
# Keys: ['Cutive Mon']
# Links: ['https://tinyurl.com/NVN-CutiveMono1']
# Images: ['https://i.postimg.cc/1z3Rk1r1/120220035-149760560147658-7702788986249011979-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/149760613480986
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: Description
# -----------------------
# Name: NVN Joshico
# Keys: ['Joshico']
# Links: ['https://tinyurl.com/NVN-JoshicoEdit']
# Images: ['https://i.postimg.cc/hvdt28bJ/120507063-149431813513866-2374517070897735959-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/149431950180519
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: dsfd
# -----------------------
# Name: NVN Dom Loves Mary Pro
# Keys: ['Dom Loves']
# Links: ['https://tinyurl.com/NVN-Dom-Loves-Mary-Pro']
# Images: ['https://i.postimg.cc/vHSsS2Zc/120121665-147858517004529-1671514488045007469-n.png']
# Post link: https://www.facebook.com/NVNFONT/posts/147860267004354
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: sdf
# -----------------------
# Name: NVN Milko Denilo
# Keys: ['Milko Denilo']
# Links: ['https://tinyurl.com/NVN-MilkoDenilo1']
# Images: ['https://i.postimg.cc/HLtH3YcC/269259615-444137287376649-1505888434596004675-n.png']
# Post link: https://www.facebook.com/NVNFONT/posts/147123490411365
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: sdf
# -----------------------
# Name: NVN DENSA
# Keys: ['DENSA']
# Links: ['https://tinyurl.com/NVN-DENSA1']
# Images: ['https://i.postimg.cc/yNJ664kq/119650451-145780410545673-5195039436559245813-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/145787640544950
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: Description
# -----------------------
# Name: NVN ROYAL
# Keys: ['NVN ROYAL']
# Links: ['https://tinyurl.com/2p8m2cfk']
# Images: ['https://i.postimg.cc/fLrxthvx/119227744-144792317311149-1812670532564856433-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/144794657310915
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: dsfd
# -----------------------
# Name: NVN Geminian Script
# Keys: ['Geminian']
# Links: ['https://tinyurl.com/NVN-Geminian']
# Images: ['https://i.postimg.cc/BQGCxJ0g/119668536-144477237342657-687217634715384644-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/144478560675858
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: sdf
# -----------------------
# Name: NVN Humble Hearts
# Keys: ['Humble Hearts']
# Links: ['https://tinyurl.com/NVN-Humble-Heart']
# Images: ['https://i.postimg.cc/mDHQH5pJ/119088052-143397910783923-2662380713078933967-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/143399460783768
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: sdf
# -----------------------
# Name: NVN Milotte
# Keys: ['Milotte']
# Links: ['https://tinyurl.com/NVN-MilottePro']
# Images: ['https://i.postimg.cc/pLmYvrYP/119107491-142374114219636-3702700874785236264-n.png']
# Post link: https://www.facebook.com/NVNFONT/posts/142375684219479
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: Description
# -----------------------
# Name: NVN AMETIST 2
# Keys: ['NVN AMETIST 2']
# Links: ['https://tinyurl.com/NVN-AMETIST']
# Images: ['https://i.postimg.cc/W38Jgc69/118770335-140680867722294-1893429047243189899-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/140679894389058
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['2']
# Description: dsfd
# -----------------------
# Name: NVN Helmswald Post
# Keys: ['Helmswald']
# Links: ['https://tinyurl.com/NVN-HelmswaldPost1']
# Images: ['https://i.postimg.cc/KjKvz693/118545860-138340087956372-7641791311964667332-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/138341847956196
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['4']
# Description: sdf
# -----------------------
# Name: NVN Space Quest
# Keys: ['Space Quest']
# Links: ['https://tinyurl.com/NVN-Space-Quest']
# Images: ['https://i.postimg.cc/Qt7jZQVc/118287549-137929484664099-78360966751675239-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/137930721330642
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['4']
# Description: sdf
# -----------------------
# Name: NVN Anaximander Rough
# Keys: ['Anaximander Rough']
# Links: ['https://tinyurl.com/NVN-Anaximander']
# Images: ['https://i.postimg.cc/NjR8FVVn/118092273-135605984896449-4169116477039762134-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/135606151563099
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['4']
# Description: Description
# -----------------------
# Name: NVN Funboo
# Keys: ['NVN Funboo']
# Links: ['https://tinyurl.com/NVN-Funboo']
# Images: ['https://i.postimg.cc/TwxTGybS/269919499-444139427376435-4913374993461666299-n.png']
# Post link: https://www.facebook.com/NVNFONT/posts/135235428266838
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['4']
# Description: dsfd
# -----------------------
# Name: NVN Bubble Jelly
# Keys: ['Bubble Jelly']
# Links: ['https://tinyurl.com/NVN-Bubble-Jelly']
# Images: ['https://i.postimg.cc/vBSMn0kR/117864717-134139188376462-2256086512877300369-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/134139185043129
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['4']
# Description: sdf
# -----------------------
# Name: NVN Winslow Book
# Keys: ['Winslow Book']
# Links: ['https://tinyurl.com/NVN-Winslow-Book']
# Images: ['https://i.postimg.cc/HLF1sryH/117894689-133770121746702-7905966117809526692-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/133770461746668
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: ['4']
# Description: sdf
# -----------------------
# Name: NVN Daikon
# Keys: ['Daikon']
# Links: ['https://tinyurl.com/NVN-Daikon']
# Images: ['https://i.postimg.cc/vBX7tVtw/117640258-132649148525466-2298825419230114478-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/132649408525440
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: []
# Description: Không có mô tả
# -----------------------
# Name: NVN CHINA FAD
# Keys: ['CHINA FAD']
# Links: ['https://tinyurl.com/NVN-CHINA-FAD']
# Images: ['https://i.postimg.cc/qqJ06zpF/117404994-131459798644401-3497272711566139241-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/131459795311068
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: []
# Description: Không có mô tả
# -----------------------
# Name: NVN PARNAS
# Keys: ['PARNAS']
# Links: ['https://tinyurl.com/NVN-PARNAS']
# Images: ['https://i.postimg.cc/nVXfgbCB/117291139-129517545505293-6294977230487459753-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/129519785505069
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: []
# Description: Không có mô tả
# -----------------------
# Name: NVN Megatype
# Keys: ['Megatype']
# Links: ['https://tinyurl.com/NVN-Megatype']
# Images: ['https://i.postimg.cc/c4chc60m/117329919-128324438957937-2539237577991591312-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/128324492291265
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: []
# Description: Không có mô tả
# -----------------------
# Name: NVN Pincoya
# Keys: ['Pincoya']
# Links: ['https://tinyurl.com/NVN-Pincoya']
# Images: ['https://i.postimg.cc/kGgG3jRD/117298602-126996109090770-1000357030117791014-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/126998725757175
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: []
# Description: Không có mô tả
# -----------------------
# Name: NVN Concepts
# Keys: ['Concepts']
# Links: ['https://tinyurl.com/NVN-Concepts']
# Images: ['https://i.postimg.cc/PqqdqLrF/116223617-126092159181165-5165900764011128776-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/126040625852985
# ...
# Post link: https://www.facebook.com/NVNFONT/posts/139951477795233
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: []
# Description: Không có mô tả
# -----------------------
# Name: NVN Proxima Nova Vintage
# Keys: ['font mới', 'Proxima']
# Links: ['https://by.com.vn/NVN-Proxima']
# Images: ['https://i.postimg.cc/nVPqk7Dp/274032939-478442377279473-5640128610554105117-n.png']
# Post link: https://www.facebook.com/NVNFONT/posts/478443617279349
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: []
# Description: Không có mô tả
# -----------------------
# Name: NVN Sinistre
# Keys: ['Sinistre']
# Links: ['https://by.com.vn/NVN-Sinistre']
# Images: ['https://i.postimg.cc/CMXccdBT/276119108-501870134936697-7275778852785550684-n.png']
# Post link: https://www.facebook.com/NVNFONT/posts/501870724936638
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: []
# Description: Không có mô tả
# -----------------------
# Name: NVN Rosemary Signature
# Keys: ['Rosemary ']
# Links: ['https://by.com.vn/NVN-Rosemary']
# Images: ['https://i.postimg.cc/t4ytc69f/277805629-507882551002122-3202164034323974881-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/507882531002124
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: []
# Description: Không có mô tả
# -----------------------
# Name: NVN Alpha
# Keys: ['alpha']
# Links: ['https://by.com.vn/NVN-Alpha']
# Images: ['https://i.postimg.cc/C5Tfqy1t/283254036-540505427739834-1492217404917878097-n.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/540551001068610
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: []
# Description: Không có mô tả
# -----------------------
# Name: NVN Valky
# Keys: ['valky']
# Links: ['https://by.com.vn/NVN-Valky']
# Images: ['https://i.postimg.cc/fLFFSXDR/openingartboard-4preview.jpg']
# Post link: https://www.facebook.com/NVNFONT/posts/pfbid02UrJm8V7hGeRQfz4WKU3UecmKwkSMqC1U8YAE8DJqhDs3q1v19qNzrPrBXd2ab6rhl
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: []
# Description: Không có mô tả
# -----------------------
# Name: Collage Tdric
# Keys: ['collage tdric']
# Links: ['https://www.facebook.com/tdricshare/posts/pfbid06ZNZcyBkcG3YF3dM9oBVHMrpKFBtr684XYRbLYqHNQoYVybhCkHVAXrAHQu8275Bl']
# Images: ['https://i.postimg.cc/Gt5DJPmr/received-492026109353639.webp']
# Post link: https://www.facebook.com/104530974670617/posts/pfbid0dkf3yoX6kMzaYTdSunpdzDXMsvqf6iTJXwovmDMkTPtbp8885yt6m1Cz8vMP3n54l/?sfnsn=mo
# Messages: ['Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '"Danh sách font hỗ trợ" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nhé']
# Tags: []
# Description: Không có mô tả
# -----------------------
# Name: NVN Hopeitissed
# Keys: ['hopeitissed']
# Links: ['https://by.com.vn/NVN-Hopeitissed-']
# Images: ['https://i.postimg.cc/BQRf3V44/27-08-2021.png']
# Post link: https://www.facebook.com/NVNFONT/posts/pfbid024nwHRzjzmEb4kfpwFE8f5ZNkPfoXYGjrLxeUGJnZtMJ1EQnbvS1sacgj5bdbhBmHl
# Messages: ['"Nếu bạn muốn xem list font hỗ trợ thì gửi tin nhắn', '""Danh sách font hỗ trợ"" ', 'Nếu bạn chưa like page thì truy cập vào fb.com/nvnfont like ', 'và follow để ủng hộ bọn mình nh